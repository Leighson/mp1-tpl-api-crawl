# %% [markdown]
# # Mini-Project I
# During this project, we will practice handling of complex lists and dictionaries in Python. Plus, we will learn how to work with API documentation. Don't be afraid to search for the information in the [**documentation**](https://api.tfl.gov.uk/swagger/ui/index.html?url=/swagger/docs/v1#!/AccidentStats/AccidentStats_Get).
#
# Let's go to the tasks, we have some parsing to do :)!!

# %%
import requests as re
import json
import os

# %% [markdown]
# ## Demo

# %%
tfl_primary = os.environ.get('TFL_PRIMARY')
tfl_secondary = os.environ.get('TFL_SECONDARY')

print(tfl_primary)
print(tfl_secondary)
# Out:
# d46bee05e8624218ba3b87b8bb0acf9c
# d39ca07e21b54211841b26f7d04bc458

# %%
url = 'https://api.tfl.gov.uk/AirQuality'
auth = f'?app_id={tfl_primary}&app_key={tfl_secondary}'

print(url+auth)
# Out:
# https://api.tfl.gov.uk/AirQuality?app_id=d46bee05e8624218ba3b87b8bb0acf9c&app_key=d39ca07e21b54211841b26f7d04bc458

# %%
# We send the request to the API
res = re.get(url+auth)

# We can check if the request was successful
res.status_code
# Out:
# 200

# %%
# We can export the information that was returned using method .json()
res.json()
# Out:
# {'$id': '1',
#  '$type': 'Tfl.Api.Presentation.Entities.LondonAirForecast, Tfl.Api.Presentation.Entities',
#  'updatePeriod': 'hourly',
#  'updateFrequency': '1',
#  'forecastURL': 'http://londonair.org.uk/forecast',
#  'disclaimerText': 'This forecast is intended to provide information on expected pollution levels in areas of significant public exposure. It may not apply in very specific locations close to unusually strong or short-lived local sources of pollution.',
#  'currentForecast': [{'$id': '2',
#    '$type': 'Tfl.Api.Presentation.Entities.CurrentForecast, Tfl.Api.Presentation.Entities',
#    'forecastType': 'Current',
#    'forecastID': '37751',
#    'forecastBand': 'Low',
#    'forecastSummary': 'Low air pollution forecast valid from Wednesday 31 August to end of Wednesday 31 August GMT',
#    'nO2Band': 'Low',
#    'o3Band': 'Low',
#    'pM10Band': 'Low',
#    'pM25Band': 'Low',
#    'sO2Band': 'Low',
#    'forecastText': 'Largely fine weather for Wednesday, with sunny spells and temperatures into the low 20s.&lt;br/&gt;&lt;br/&gt;A feed of air will continue to arrive from the North Sea on a fresh breeze, this giving good local dispersion and bringing little imported pollution.&lt;br/&gt;&lt;br/&gt;Air pollution is expected to remain &#39;Low&#39; for the following pollutants throughout the forecast period:&lt;br/&gt;&lt;br/&gt;Nitrogen Dioxide&lt;br/&gt;Ozone&lt;br/&gt;PM10 Particulate&lt;br/&gt;PM2.5 Particulate&lt;br/&gt;Sulphur Dioxide&lt;br/&gt;'},
#   {'$id': '3',
#    '$type': 'Tfl.Api.Presentation.Entities.CurrentForecast, Tfl.Api.Presentation.Entities',
#    'forecastType': 'Future',
#    'forecastID': '37752',
#    'fromDate': '2022-01-09T00:00:00Z',
#    'toDate': '2022-01-09T23:59:00Z',
#    'forecastBand': 'Low',
#    'forecastSummary': 'Low air pollution forecast valid from Thursday 1 September to end of Thursday 1 September GMT',
#    'nO2Band': 'Low',
#    'o3Band': 'Low',
#    'pM10Band': 'Low',
#    'pM25Band': 'Low',
#    'sO2Band': 'Low',
#    'forecastText': 'Further settled weather for Thursday although morning sunshine will give way to increasing cloud cover by the afternoon.&lt;br/&gt;&lt;br/&gt;A change in wind direction is also expected during the day, this introducing a feed of air that has passed over Germany and Holland before reaching Greater London. However, air mass back-trajectories show the air to be travelling at relatively high altitude over the near-continent and, as such, it is not currently expected to result in a marked import of pollution.&lt;br/&gt;&lt;br/&gt;Air pollution is currently expected to remain &#39;Low&#39; for the following pollutants throughout the forecast period:&lt;br/&gt;&lt;br/&gt;Nitrogen Dioxide&lt;br/&gt;Ozone&lt;br/&gt;PM10 Particulate&lt;br/&gt;PM2.5 Particulate&lt;br/&gt;Sulphur Dioxide&lt;br/&gt;'}]}

# %% [markdown]
# ## Task
# Parse the dictionary and print the AirQuality predictions for tomorrow

# %%
# We can export the information that was returned using method .json()
print(res.json()['currentForecast'][0]['nO2Band'])
print(res.json()['currentForecast'][0]['o3Band'])
print(res.json()['currentForecast'][0]['pM10Band'])
print(res.json()['currentForecast'][0]['pM25Band'])
print(res.json()['currentForecast'][0]['sO2Band'])
# Out:
# Low
# Low
# Low
# Low
# Low

# %%
# the air quality specific endpoint does not provide
# unique results from the main endpoint above

url_air = 'https://api.tfl.gov.uk/AirQuality/'
res_air = re.get(url_air+auth)
res_air.json()['currentForecast'][0]
# Out:
# {'$id': '2',
#  '$type': 'Tfl.Api.Presentation.Entities.CurrentForecast, Tfl.Api.Presentation.Entities',
#  'forecastType': 'Current',
#  'forecastID': '37751',
#  'forecastBand': 'Low',
#  'forecastSummary': 'Low air pollution forecast valid from Wednesday 31 August to end of Wednesday 31 August GMT',
#  'nO2Band': 'Low',
#  'o3Band': 'Low',
#  'pM10Band': 'Low',
#  'pM25Band': 'Low',
#  'sO2Band': 'Low',
#  'forecastText': 'Largely fine weather for Wednesday, with sunny spells and temperatures into the low 20s.&lt;br/&gt;&lt;br/&gt;A feed of air will continue to arrive from the North Sea on a fresh breeze, this giving good local dispersion and bringing little imported pollution.&lt;br/&gt;&lt;br/&gt;Air pollution is expected to remain &#39;Low&#39; for the following pollutants throughout the forecast period:&lt;br/&gt;&lt;br/&gt;Nitrogen Dioxide&lt;br/&gt;Ozone&lt;br/&gt;PM10 Particulate&lt;br/&gt;PM2.5 Particulate&lt;br/&gt;Sulphur Dioxide&lt;br/&gt;'}

# %% [markdown]
# ## Task
# What are the different modes of transport which are operated by Transfer for London? How many of modes do they have?
#
# Print the list with different modes of transport, plus their count. Example output:
# ```
# [bus, cable-car,.....]
# Number of different modes of transport is: xyz
# ```
#
# We need to search the documentation for correct request.

# %%
# mode is only available for tube

url_vehicle = 'https://api.tfl.gov.uk/Line/Meta/Modes'
res_vehicle = re.get(url_vehicle+auth)

def modes(url, auth, endpoint):
    
    res = re.get(url + auth)
    
    modes = []
    
    for id in res.json():
        modes.append(id[endpoint])
    
    return modes

# %%
modes(url_vehicle, auth, 'modeName')
# Out:
# ['bus',
#  'cable-car',
#  'coach',
#  'cycle',
#  'cycle-hire',
#  'dlr',
#  'elizabeth-line',
#  'interchange-keep-sitting',
#  'interchange-secure',
#  'national-rail',
#  'overground',
#  'replacement-bus',
#  'river-bus',
#  'river-tour',
#  'taxi',
#  'tram',
#  'tube',
#  'walking']

# %% [markdown]
# ## Task
# How many BikePoints in London are operated by Transfor for London? How many docks are in **all** BikePoints? There is the information for empty and full docks for each BikePoint.

# %%
url_bike = 'https://api.tfl.gov.uk/BikePoint/'
res_bike = re.get(url_bike+auth)

# %%
res_bike.json()
# Out:
# [{'$type': 'Tfl.Api.Presentation.Entities.Place, Tfl.Api.Presentation.Entities',
#   'id': 'BikePoints_84',
#   'url': '/Place/BikePoints_84',
#   'commonName': 'Breams Buildings, Holborn',
#   'placeType': 'BikePoint',
#   'additionalProperties': [{'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'TerminalName',
#     'sourceSystemKey': 'BikePoints',
#     'value': '003449',
#     'modified': '2022-08-30T20:04:41.857Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Installed',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'true',
#     'modified': '2022-08-30T20:04:41.857Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Locked',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-30T20:04:41.857Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'InstallDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '1279020240000',
#     'modified': '2022-08-30T20:04:41.857Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'RemovalDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T20:04:41.857Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Temporary',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-30T20:04:41.857Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '0',
#     'modified': '2022-08-30T20:04:41.857Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEmptyDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '24',
#     'modified': '2022-08-30T20:04:41.857Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '25',
#     'modified': '2022-08-30T20:04:41.857Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbStandardBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T20:04:41.857Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T20:04:41.857Z'}],
#   'children': [],
#   'childrenUrls': [],
#   'lat': 51.515937,
#   'lon': -0.111778},
#  {'$type': 'Tfl.Api.Presentation.Entities.Place, Tfl.Api.Presentation.Entities',
#   'id': 'BikePoints_85',
#   'url': '/Place/BikePoints_85',
#   'commonName': 'Tanner Street, Bermondsey',
#   'placeType': 'BikePoint',
#   'additionalProperties': [{'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'TerminalName',
#     'sourceSystemKey': 'BikePoints',
#     'value': '000994',
#     'modified': '2022-08-31T00:23:43.803Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Installed',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'true',
#     'modified': '2022-08-31T00:23:43.803Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Locked',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-31T00:23:43.803Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'InstallDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '1279026060000',
#     'modified': '2022-08-31T00:23:43.803Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'RemovalDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-31T00:23:43.803Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Temporary',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-31T00:23:43.803Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '22',
#     'modified': '2022-08-31T00:23:43.803Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEmptyDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '19',
#     'modified': '2022-08-31T00:23:43.803Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '41',
#     'modified': '2022-08-31T00:23:43.803Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbStandardBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-31T00:23:43.803Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-31T00:23:43.803Z'}],
#   'children': [],
#   'childrenUrls': [],
#   'lat': 51.500647,
#   'lon': -0.0786},
#  {'$type': 'Tfl.Api.Presentation.Entities.Place, Tfl.Api.Presentation.Entities',
#   'id': 'BikePoints_86',
#   'url': '/Place/BikePoints_86',
#   'commonName': 'Sancroft Street, Vauxhall',
#   'placeType': 'BikePoint',
#   'additionalProperties': [{'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'TerminalName',
#     'sourceSystemKey': 'BikePoints',
#     'value': '003434',
#     'modified': '2022-08-30T22:48:33.377Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Installed',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'true',
#     'modified': '2022-08-30T22:48:33.377Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Locked',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-30T22:48:33.377Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'InstallDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '1279027140000',
#     'modified': '2022-08-30T22:48:33.377Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'RemovalDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T22:48:33.377Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Temporary',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-30T22:48:33.377Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '17',
#     'modified': '2022-08-30T22:48:33.377Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEmptyDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '7',
#     'modified': '2022-08-30T22:48:33.377Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '24',
#     'modified': '2022-08-30T22:48:33.377Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbStandardBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T22:48:33.377Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T22:48:33.377Z'}],
#   'children': [],
#   'childrenUrls': [],
#   'lat': 51.489479,
#   'lon': -0.115156},
#  {'$type': 'Tfl.Api.Presentation.Entities.Place, Tfl.Api.Presentation.Entities',
#   'id': 'BikePoints_87',
#   'url': '/Place/BikePoints_87',
#   'commonName': 'Devonshire Square, Liverpool Street',
#   'placeType': 'BikePoint',
#   'additionalProperties': [{'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'TerminalName',
#     'sourceSystemKey': 'BikePoints',
#     'value': '003438',
#     'modified': '2022-08-31T02:20:09.177Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Installed',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'true',
#     'modified': '2022-08-31T02:20:09.177Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Locked',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-31T02:20:09.177Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'InstallDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '1279027680000',
#     'modified': '2022-08-31T02:20:09.177Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'RemovalDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-31T02:20:09.177Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Temporary',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-31T02:20:09.177Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '1',
#     'modified': '2022-08-31T02:20:09.177Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEmptyDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '15',
#     'modified': '2022-08-31T02:20:09.177Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '16',
#     'modified': '2022-08-31T02:20:09.177Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbStandardBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-31T02:20:09.177Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-31T02:20:09.177Z'}],
#   'children': [],
#   'childrenUrls': [],
#   'lat': 51.516468,
#   'lon': -0.079684},
#  {'$type': 'Tfl.Api.Presentation.Entities.Place, Tfl.Api.Presentation.Entities',
#   'id': 'BikePoints_88',
#   'url': '/Place/BikePoints_88',
#   'commonName': 'Bayley Street , Bloomsbury',
#   'placeType': 'BikePoint',
#   'additionalProperties': [{'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'TerminalName',
#     'sourceSystemKey': 'BikePoints',
#     'value': '001006',
#     'modified': '2022-08-30T21:23:54.66Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Installed',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'true',
#     'modified': '2022-08-30T21:23:54.66Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Locked',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-30T21:23:54.66Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'InstallDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '1279028280000',
#     'modified': '2022-08-30T21:23:54.66Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'RemovalDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T21:23:54.66Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Temporary',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-30T21:23:54.66Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '0',
#     'modified': '2022-08-30T21:23:54.66Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEmptyDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '22',
#     'modified': '2022-08-30T21:23:54.66Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '25',
#     'modified': '2022-08-30T21:23:54.66Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbStandardBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T21:23:54.66Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T21:23:54.66Z'}],
#   'children': [],
#   'childrenUrls': [],
#   'lat': 51.518587,
#   'lon': -0.132053},
#  {'$type': 'Tfl.Api.Presentation.Entities.Place, Tfl.Api.Presentation.Entities',
#   'id': 'BikePoints_89',
#   'url': '/Place/BikePoints_89',
#   'commonName': 'Tavistock Place, Bloomsbury',
#   'placeType': 'BikePoint',
#   'additionalProperties': [{'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'TerminalName',
#     'sourceSystemKey': 'BikePoints',
#     'value': '003439',
#     'modified': '2022-08-31T00:06:42.14Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Installed',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'true',
#     'modified': '2022-08-31T00:06:42.14Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Locked',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-31T00:06:42.14Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'InstallDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '1279029360000',
#     'modified': '2022-08-31T00:06:42.14Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'RemovalDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-31T00:06:42.14Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Temporary',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-31T00:06:42.14Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '3',
#     'modified': '2022-08-31T00:06:42.14Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEmptyDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '15',
#     'modified': '2022-08-31T00:06:42.14Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '19',
#     'modified': '2022-08-31T00:06:42.14Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbStandardBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-31T00:06:42.14Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-31T00:06:42.14Z'}],
#   'children': [],
#   'childrenUrls': [],
#   'lat': 51.52625,
#   'lon': -0.123509},
#  {'$type': 'Tfl.Api.Presentation.Entities.Place, Tfl.Api.Presentation.Entities',
#   'id': 'BikePoints_90',
#   'url': '/Place/BikePoints_90',
#   'commonName': 'Harrington Square 1, Camden Town',
#   'placeType': 'BikePoint',
#   'additionalProperties': [{'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'TerminalName',
#     'sourceSystemKey': 'BikePoints',
#     'value': '001038',
#     'modified': '2022-08-30T23:43:39.773Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Installed',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'true',
#     'modified': '2022-08-30T23:43:39.773Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Locked',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-30T23:43:39.773Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'InstallDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '1279030020000',
#     'modified': '2022-08-30T23:43:39.773Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'RemovalDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T23:43:39.773Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Temporary',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-30T23:43:39.773Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '7',
#     'modified': '2022-08-30T23:43:39.773Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEmptyDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '20',
#     'modified': '2022-08-30T23:43:39.773Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '27',
#     'modified': '2022-08-30T23:43:39.773Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbStandardBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T23:43:39.773Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T23:43:39.773Z'}],
#   'children': [],
#   'childrenUrls': [],
#   'lat': 51.533019,
#   'lon': -0.139174},
#  {'$type': 'Tfl.Api.Presentation.Entities.Place, Tfl.Api.Presentation.Entities',
#   'id': 'BikePoints_91',
#   'url': '/Place/BikePoints_91',
#   'commonName': 'Walnut Tree Walk, Vauxhall',
#   'placeType': 'BikePoint',
#   'additionalProperties': [{'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'TerminalName',
#     'sourceSystemKey': 'BikePoints',
#     'value': '001076',
#     'modified': '2022-08-30T22:24:55.757Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Installed',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'true',
#     'modified': '2022-08-30T22:24:55.757Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Locked',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-30T22:24:55.757Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'InstallDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '1279036740000',
#     'modified': '2022-08-30T22:24:55.757Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'RemovalDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T22:24:55.757Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Temporary',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-30T22:24:55.757Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '12',
#     'modified': '2022-08-30T22:24:55.757Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEmptyDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '7',
#     'modified': '2022-08-30T22:24:55.757Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '20',
#     'modified': '2022-08-30T22:24:55.757Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbStandardBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T22:24:55.757Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T22:24:55.757Z'}],
#   'children': [],
#   'childrenUrls': [],
#   'lat': 51.493686,
#   'lon': -0.111014},
#  {'$type': 'Tfl.Api.Presentation.Entities.Place, Tfl.Api.Presentation.Entities',
#   'id': 'BikePoints_92',
#   'url': '/Place/BikePoints_92',
#   'commonName': 'Borough Road, Elephant & Castle',
#   'placeType': 'BikePoint',
#   'additionalProperties': [{'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'TerminalName',
#     'sourceSystemKey': 'BikePoints',
#     'value': '001082',
#     'modified': '2022-08-31T01:57:53.29Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Installed',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'true',
#     'modified': '2022-08-31T01:57:53.29Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Locked',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-31T01:57:53.29Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'InstallDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '1279037040000',
#     'modified': '2022-08-31T01:57:53.29Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'RemovalDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-31T01:57:53.29Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Temporary',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-31T01:57:53.29Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '7',
#     'modified': '2022-08-31T01:57:53.29Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEmptyDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '34',
#     'modified': '2022-08-31T01:57:53.29Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '41',
#     'modified': '2022-08-31T01:57:53.29Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbStandardBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-31T01:57:53.29Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-31T01:57:53.29Z'}],
#   'children': [],
#   'childrenUrls': [],
#   'lat': 51.498898,
#   'lon': -0.10044},
#  {'$type': 'Tfl.Api.Presentation.Entities.Place, Tfl.Api.Presentation.Entities',
#   'id': 'BikePoints_93',
#   'url': '/Place/BikePoints_93',
#   'commonName': 'Cloudesley Road, Angel',
#   'placeType': 'BikePoint',
#   'additionalProperties': [{'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'TerminalName',
#     'sourceSystemKey': 'BikePoints',
#     'value': '002586',
#     'modified': '2022-08-30T23:18:37.6Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Installed',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'true',
#     'modified': '2022-08-30T23:18:37.6Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Locked',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-30T23:18:37.6Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'InstallDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '1279037760000',
#     'modified': '2022-08-30T23:18:37.6Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'RemovalDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T23:18:37.6Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Temporary',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-30T23:18:37.6Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '11',
#     'modified': '2022-08-30T23:18:37.6Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEmptyDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '26',
#     'modified': '2022-08-30T23:18:37.6Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '37',
#     'modified': '2022-08-30T23:18:37.6Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbStandardBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T23:18:37.6Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T23:18:37.6Z'}],
#   'children': [],
#   'childrenUrls': [],
#   'lat': 51.534408,
#   'lon': -0.109025},
#  {'$type': 'Tfl.Api.Presentation.Entities.Place, Tfl.Api.Presentation.Entities',
#   'id': 'BikePoints_94',
#   'url': '/Place/BikePoints_94',
#   'commonName': 'Bricklayers Arms, Borough',
#   'placeType': 'BikePoint',
#   'additionalProperties': [{'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'TerminalName',
#     'sourceSystemKey': 'BikePoints',
#     'value': '001070',
#     'modified': '2022-08-31T02:09:10.44Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Installed',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'true',
#     'modified': '2022-08-31T02:09:10.44Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Locked',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-31T02:09:10.44Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'InstallDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '1279038420000',
#     'modified': '2022-08-31T02:09:10.44Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'RemovalDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-31T02:09:10.44Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Temporary',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-31T02:09:10.44Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '24',
#     'modified': '2022-08-31T02:09:10.44Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEmptyDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '3',
#     'modified': '2022-08-31T02:09:10.44Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '28',
#     'modified': '2022-08-31T02:09:10.44Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbStandardBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-31T02:09:10.44Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-31T02:09:10.44Z'}],
#   'children': [],
#   'childrenUrls': [],
#   'lat': 51.495061,
#   'lon': -0.085814},
#  {'$type': 'Tfl.Api.Presentation.Entities.Place, Tfl.Api.Presentation.Entities',
#   'id': 'BikePoints_95',
#   'url': '/Place/BikePoints_95',
#   'commonName': 'Aldersgate Street, Barbican',
#   'placeType': 'BikePoint',
#   'additionalProperties': [{'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'TerminalName',
#     'sourceSystemKey': 'BikePoints',
#     'value': '001065',
#     'modified': '2022-08-30T23:17:37.423Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Installed',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'true',
#     'modified': '2022-08-30T23:17:37.423Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Locked',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-30T23:17:37.423Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'InstallDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '1279096560000',
#     'modified': '2022-08-30T23:17:37.423Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'RemovalDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T23:17:37.423Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Temporary',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-30T23:17:37.423Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '1',
#     'modified': '2022-08-30T23:17:37.423Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEmptyDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '14',
#     'modified': '2022-08-30T23:17:37.423Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '15',
#     'modified': '2022-08-30T23:17:37.423Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbStandardBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T23:17:37.423Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T23:17:37.423Z'}],
#   'children': [],
#   'childrenUrls': [],
#   'lat': 51.520841,
#   'lon': -0.09734},
#  {'$type': 'Tfl.Api.Presentation.Entities.Place, Tfl.Api.Presentation.Entities',
#   'id': 'BikePoints_96',
#   'url': '/Place/BikePoints_96',
#   'commonName': 'Falkirk Street, Hoxton',
#   'placeType': 'BikePoint',
#   'additionalProperties': [{'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'TerminalName',
#     'sourceSystemKey': 'BikePoints',
#     'value': '001047',
#     'modified': '2022-08-30T21:03:51.08Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Installed',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'true',
#     'modified': '2022-08-30T21:03:51.08Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Locked',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-30T21:03:51.08Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'InstallDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '1279096980000',
#     'modified': '2022-08-30T21:03:51.08Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'RemovalDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T21:03:51.08Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Temporary',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-30T21:03:51.08Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '1',
#     'modified': '2022-08-30T21:03:51.08Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEmptyDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '24',
#     'modified': '2022-08-30T21:03:51.08Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '26',
#     'modified': '2022-08-30T21:03:51.08Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbStandardBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T21:03:51.08Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T21:03:51.08Z'}],
#   'children': [],
#   'childrenUrls': [],
#   'lat': 51.53095,
#   'lon': -0.078505},
#  {'$type': 'Tfl.Api.Presentation.Entities.Place, Tfl.Api.Presentation.Entities',
#   'id': 'BikePoints_97',
#   'url': '/Place/BikePoints_97',
#   'commonName': 'Gloucester Road (North), Kensington',
#   'placeType': 'BikePoint',
#   'additionalProperties': [{'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'TerminalName',
#     'sourceSystemKey': 'BikePoints',
#     'value': '003447',
#     'modified': '2022-08-30T23:10:36.747Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Installed',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'true',
#     'modified': '2022-08-30T23:10:36.747Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Locked',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-30T23:10:36.747Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'InstallDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '1279097580000',
#     'modified': '2022-08-30T23:10:36.747Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'RemovalDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T23:10:36.747Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Temporary',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-30T23:10:36.747Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '0',
#     'modified': '2022-08-30T23:10:36.747Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEmptyDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '18',
#     'modified': '2022-08-30T23:10:36.747Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '18',
#     'modified': '2022-08-30T23:10:36.747Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbStandardBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T23:10:36.747Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T23:10:36.747Z'}],
#   'children': [],
#   'childrenUrls': [],
#   'lat': 51.497924,
#   'lon': -0.183834},
#  {'$type': 'Tfl.Api.Presentation.Entities.Place, Tfl.Api.Presentation.Entities',
#   'id': 'BikePoints_98',
#   'url': '/Place/BikePoints_98',
#   'commonName': 'Hampstead Road, Euston',
#   'placeType': 'BikePoint',
#   'additionalProperties': [{'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'TerminalName',
#     'sourceSystemKey': 'BikePoints',
#     'value': '000972',
#     'modified': '2022-08-31T00:48:46.943Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Installed',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'true',
#     'modified': '2022-08-31T00:48:46.943Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Locked',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-31T00:48:46.943Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'InstallDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '1279099080000',
#     'modified': '2022-08-31T00:48:46.943Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'RemovalDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-31T00:48:46.943Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Temporary',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-31T00:48:46.943Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '1',
#     'modified': '2022-08-31T00:48:46.943Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEmptyDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '51',
#     'modified': '2022-08-31T00:48:46.943Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '54',
#     'modified': '2022-08-31T00:48:46.943Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbStandardBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-31T00:48:46.943Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-31T00:48:46.943Z'}],
#   'children': [],
#   'childrenUrls': [],
#   'lat': 51.525542,
#   'lon': -0.138231},
#  {'$type': 'Tfl.Api.Presentation.Entities.Place, Tfl.Api.Presentation.Entities',
#   'id': 'BikePoints_99',
#   'url': '/Place/BikePoints_99',
#   'commonName': 'Old Quebec Street, Marylebone',
#   'placeType': 'BikePoint',
#   'additionalProperties': [{'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'TerminalName',
#     'sourceSystemKey': 'BikePoints',
#     'value': '001085',
#     'modified': '2022-08-31T02:27:11.927Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Installed',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'true',
#     'modified': '2022-08-31T02:27:11.927Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Locked',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-31T02:27:11.927Z'},
# ...
#     'category': 'Description',
#     'key': 'NbEBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T22:18:56.6Z'}],
#   'children': [],
#   'childrenUrls': [],
#   'lat': 51.514311,
#   'lon': -0.200838},
#  {'$type': 'Tfl.Api.Presentation.Entities.Place, Tfl.Api.Presentation.Entities',
#   'id': 'BikePoints_29',
#   'url': '/Place/BikePoints_29',
#   'commonName': 'Hereford Road, Bayswater',
#   'placeType': 'BikePoint',
#   'additionalProperties': [{'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'TerminalName',
#     'sourceSystemKey': 'BikePoints',
#     'value': '001016',
#     'modified': '2022-08-30T21:30:53.89Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Installed',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'true',
#     'modified': '2022-08-30T21:30:53.89Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Locked',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-30T21:30:53.89Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'InstallDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '1278501180000',
#     'modified': '2022-08-30T21:30:53.89Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'RemovalDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T21:30:53.89Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Temporary',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-30T21:30:53.89Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '14',
#     'modified': '2022-08-30T21:30:53.89Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEmptyDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '7',
#     'modified': '2022-08-30T21:30:53.89Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '22',
#     'modified': '2022-08-30T21:30:53.89Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbStandardBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T21:30:53.89Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T21:30:53.89Z'}],
#   'children': [],
#   'childrenUrls': [],
#   'lat': 51.513735,
#   'lon': -0.193487},
#  {'$type': 'Tfl.Api.Presentation.Entities.Place, Tfl.Api.Presentation.Entities',
#   'id': 'BikePoints_742',
#   'url': '/Place/BikePoints_742',
#   'commonName': 'Blenheim Crescent, Ladbroke Grove',
#   'placeType': 'BikePoint',
#   'additionalProperties': [{'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'TerminalName',
#     'sourceSystemKey': 'BikePoints',
#     'value': '300090',
#     'modified': '2022-08-30T22:54:42.237Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Installed',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'true',
#     'modified': '2022-08-30T22:54:42.237Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Locked',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-30T22:54:42.237Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'InstallDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '1385649540000',
#     'modified': '2022-08-30T22:54:42.237Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'RemovalDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T22:54:42.237Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Temporary',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-30T22:54:42.237Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '8',
#     'modified': '2022-08-30T22:54:42.237Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEmptyDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '14',
#     'modified': '2022-08-30T22:54:42.237Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '22',
#     'modified': '2022-08-30T22:54:42.237Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbStandardBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T22:54:42.237Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T22:54:42.237Z'}],
#   'children': [],
#   'childrenUrls': [],
#   'lat': 51.515108,
#   'lon': -0.208565},
#  {'$type': 'Tfl.Api.Presentation.Entities.Place, Tfl.Api.Presentation.Entities',
#   'id': 'BikePoints_225',
#   'url': '/Place/BikePoints_225',
#   'commonName': 'Notting Hill Gate Station, Notting Hill',
#   'placeType': 'BikePoint',
#   'additionalProperties': [{'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'TerminalName',
#     'sourceSystemKey': 'BikePoints',
#     'value': '001182',
#     'modified': '2022-08-31T01:56:53.273Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Installed',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'true',
#     'modified': '2022-08-31T01:56:53.273Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Locked',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-31T01:56:53.273Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'InstallDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '1279616280000',
#     'modified': '2022-08-31T01:56:53.273Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'RemovalDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-31T01:56:53.273Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Temporary',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-31T01:56:53.273Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '1',
#     'modified': '2022-08-31T01:56:53.273Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEmptyDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '29',
#     'modified': '2022-08-31T01:56:53.273Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '30',
#     'modified': '2022-08-31T01:56:53.273Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbStandardBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-31T01:56:53.273Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-31T01:56:53.273Z'}],
#   'children': [],
#   'childrenUrls': [],
#   'lat': 51.509353,
#   'lon': -0.196422},
#  {'$type': 'Tfl.Api.Presentation.Entities.Place, Tfl.Api.Presentation.Entities',
#   'id': 'BikePoints_643',
#   'url': '/Place/BikePoints_643',
#   'commonName': "All Saints' Road, Portobello",
#   'placeType': 'BikePoint',
#   'additionalProperties': [{'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'TerminalName',
#     'sourceSystemKey': 'BikePoints',
#     'value': '300026',
#     'modified': '2022-08-30T20:55:50.273Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Installed',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'true',
#     'modified': '2022-08-30T20:55:50.273Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Locked',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-30T20:55:50.273Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'InstallDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '1382010720000',
#     'modified': '2022-08-30T20:55:50.273Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'RemovalDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T20:55:50.273Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Temporary',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-30T20:55:50.273Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '5',
#     'modified': '2022-08-30T20:55:50.273Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEmptyDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '17',
#     'modified': '2022-08-30T20:55:50.273Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '22',
#     'modified': '2022-08-30T20:55:50.273Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbStandardBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T20:55:50.273Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-30T20:55:50.273Z'}],
#   'children': [],
#   'childrenUrls': [],
#   'lat': 51.519042,
#   'lon': -0.204764},
#  {'$type': 'Tfl.Api.Presentation.Entities.Place, Tfl.Api.Presentation.Entities',
#   'id': 'BikePoints_758',
#   'url': '/Place/BikePoints_758',
#   'commonName': 'Westbourne Park Road, Portobello',
#   'placeType': 'BikePoint',
#   'additionalProperties': [{'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'TerminalName',
#     'sourceSystemKey': 'BikePoints',
#     'value': '300057',
#     'modified': '2022-08-31T02:12:10.527Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Installed',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'true',
#     'modified': '2022-08-31T02:12:10.527Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Locked',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-31T02:12:10.527Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'InstallDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '1389178020000',
#     'modified': '2022-08-31T02:12:10.527Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'RemovalDate',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-31T02:12:10.527Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'Temporary',
#     'sourceSystemKey': 'BikePoints',
#     'value': 'false',
#     'modified': '2022-08-31T02:12:10.527Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '2',
#     'modified': '2022-08-31T02:12:10.527Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEmptyDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '20',
#     'modified': '2022-08-31T02:12:10.527Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbDocks',
#     'sourceSystemKey': 'BikePoints',
#     'value': '23',
#     'modified': '2022-08-31T02:12:10.527Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbStandardBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-31T02:12:10.527Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AdditionalProperties, Tfl.Api.Presentation.Entities',
#     'category': 'Description',
#     'key': 'NbEBikes',
#     'sourceSystemKey': 'BikePoints',
#     'value': '',
#     'modified': '2022-08-31T02:12:10.527Z'}],
#   'children': [],
#   'childrenUrls': [],
#   'lat': 51.51787,
#   'lon': -0.201005}]

# %%
print(len(res_vehicle.json()))
print(len(modes(url_bike, auth, 'additionalProperties')))
# Out:
# 18
# 785

# %% [markdown]
# ## Task
# How many tube and bus lines are in London? Print names of all tube lines.

# %% [markdown]
# ## Task
# How many station has `victoria` line?

# %% [markdown]
# ## Task
# Plan the journey from Heathrow Airport to Tower Bridge using Bus and Tube? Which way is faster? Example output:
# ```
# Planned duration:
# Bus: x minutes
# Tube: y minutes
# ```
#
# We need to search the documentation for correct requests and parameters we need.
